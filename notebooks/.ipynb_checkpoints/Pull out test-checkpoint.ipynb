# %%
using Amaru

# %%
# Mesh generation
bls = [
       Block3D( [0 0 0; 1.0 6.0 1.0], nx=1, ny=10, nz=1),
       BlockInset( [0.5 3 0.5; 0.5 6.0 0.5], curvetype="polyline"),
      ]

msh = Mesh(bls, verbose=true)

# Tagging entities
bar_points  = sort(msh.cells[:lines][:points], by=get_y)
cell_points = msh.cells[:solids][:points]

tag!(bar_points[end], "tip")
tag!(cell_points, "fixed_points")
# Out:
# Mesh generation:
#   analyzing 2 block(s)
#   3D mesh
#      55 points obtained
#      20 cells obtained
#      42 faces obtained
#      84 surface edges obtained
#       4 intersections found
#   done.

# %%
mplot(msh)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2bc61bd790>)

# %%
# FEM analysis

phi = 30*pi/180; dm=0.15138; c=20.0
mats = [
        MaterialBind(:solids, ElasticSolid(E=24e3, nu=0.2)),
        MaterialBind(:lines, ElasticRod(E=1.e8, A=0.005)),
        MaterialBind(:lines, ElasticRod(E=200e6, A=0.00011)),
        MaterialBind(:joints1D, CEBJoint1D(TauM=12, TauR=3, s1=0.001, s2=0.0011, s3=0.004, alpha=0.5, beta=0.5,
                                           ks=(12/0.001)*5, kn=50000, A=0.005), iptag="joint_ips")
       ]

log_tip     = Logger(:node, "tip")
log_jnt_ip  = Logger(:ip, :(tag=="joint_ips" && y>5.8))
log_jnt_ips = GroupLogger(:ips, "joint_ips", by=get_y)
logs = [ log_tip, log_jnt_ip, log_jnt_ips ]

dom = Domain(msh, mats, logs);
# Out:
# Domain setup:
#   3D domain general model
#      55 nodes
#      20 elements
#      42 faces
#      84 edges
#       4 materials
#       3 loggers
#   done.

# %%
reset!(dom)
bc1 = BC(:node, "fixed_points", :(ux=0, uy=0, uz=0))
bc2 = BC(:node, "tip", :(uy=+0.005))

solve!(dom, [bc1, bc2], nincs=40, autoinc=true, verbose=true)
# Out:
# FEM analysis:
#   unknown dofs: 32
#   increment 1 from t=0.0 to t=0.025 (dt=0.025):
#     it 1   residue: 7.1487e-01
#     it 2   residue: 4.8636e-02
#     it 3   residue: 2.0247e-02
#     it 4   residue: 8.9860e-03
#   increment 2 from t=0.025 to t=0.05 (dt=0.025):
#     it 1   residue: 2.2445e-01
#     it 2   residue: 6.3759e-02
#     it 3   residue: 2.3391e-02
#     it 4   residue: 7.6070e-03
#   increment 3 from t=0.05 to t=0.075 (dt=0.025):
#     it 1   residue: 1.5242e-01
#     it 2   residue: 4.0503e-02
#     it 3   residue: 1.2521e-02
#     it 4   residue: 3.5846e-03
#   increment 4 from t=0.075 to t=0.1 (dt=0.025):
#     it 1   residue: 1.2248e-01
#     it 2   residue: 3.0321e-02
#     it 3   residue: 8.3732e-03
#   increment 5 from t=0.1 to t=0.125 (dt=0.025):
#     it 1   residue: 1.0539e-01
#     it 2   residue: 2.4988e-02
#     it 3   residue: 6.3241e-03
#   increment 6 from t=0.125 to t=0.15 (dt=0.025):
#     it 1   residue: 9.3841e-02
#     it 2   residue: 2.1126e-02
#     it 3   residue: 4.9768e-03
#   increment 7 from t=0.15 to t=0.175 (dt=0.025):
#     it 1   residue: 8.5431e-02
#     it 2   residue: 1.8368e-02
#     it 3   residue: 4.0687e-03
#   increment 8 from t=0.175 to t=0.2 (dt=0.025):
#     it 1   residue: 7.8958e-02
#     it 2   residue: 1.6288e-02
#     it 3   residue: 3.4180e-03
#   increment 9 from t=0.2 to t=0.225 (dt=0.025):
#     it 1   residue: 8.9966e-02
#     it 2   residue: 1.4749e-02
#     it 3   residue: 2.9539e-03
#   increment 10 from t=0.225 to t=0.25 (dt=0.025):
#     it 1   residue: 4.3596e-01
#     it 2   residue: 1.2627e-02
#     it 3   residue: 2.3363e-03
#   increment 11 from t=0.25 to t=0.275 (dt=0.025):
#     it 1   residue: 1.3150e-01
#     it 2   residue: 1.3160e-02
#     it 3   residue: 2.3308e-03
#   increment 12 from t=0.275 to t=0.3 (dt=0.025):
#     it 1   residue: 9.5757e-02
#     it 2   residue: 1.3577e-02
#     it 3   residue: 1.6817e-03
#   increment 13 from t=0.3 to t=0.325 (dt=0.025):
#     it 1   residue: 1.4387e-01
#     it 2   residue: 3.3316e-02
#     it 3   residue: 1.2756e-03
#   increment 14 from t=0.325 to t=0.35 (dt=0.025):
#     it 1   residue: 2.7250e-01
#     it 2   residue: 6.9265e-03
#   increment 15 from t=0.35 to t=0.375 (dt=0.025):
#     it 1   residue: 2.4672e-01
#     it 2   residue: 4.9962e-02
#     it 3   residue: 1.6642e-02
#     it 4   residue: 4.6628e-03
#   increment 16 from t=0.375 to t=0.4 (dt=0.025):
#     it 1   residue: 1.1098e-01
#     it 2   residue: 2.3946e-02
#     it 3   residue: 5.5844e-03
#   increment 17 from t=0.4 to t=0.425 (dt=0.025):
#     it 1   residue: 8.3909e-02
#     it 2   residue: 1.6157e-02
#     it 3   residue: 3.0826e-03
#   increment 18 from t=0.425 to t=0.45 (dt=0.025):
#     it 1   residue: 6.6109e-02
#     it 2   residue: 1.1625e-02
#     it 3   residue: 1.9257e-03
#   increment 19 from t=0.45 to t=0.475 (dt=0.025):
#     it 1   residue: 5.5966e-02
#     it 2   residue: 9.0556e-03
#   increment 20 from t=0.475 to t=0.5 (dt=0.025):
#     it 1   residue: 4.7216e-02
#     it 2   residue: 7.1737e-03
#   increment 21 from t=0.5 to t=0.525 (dt=0.025):
#     it 1   residue: 4.3198e-02
#     it 2   residue: 6.1356e-03
#   increment 22 from t=0.525 to t=0.55 (dt=0.025):
#     it 1   residue: 3.9921e-02
#     it 2   residue: 5.3419e-03
#   increment 23 from t=0.55 to t=0.575 (dt=0.025):
#     it 1   residue: 3.7245e-02
#     it 2   residue: 4.7230e-03
#   increment 24 from t=0.575 to t=0.6 (dt=0.025):
#     it 1   residue: 3.5011e-02
#     it 2   residue: 4.2279e-03
#   increment 25 from t=0.6 to t=0.625 (dt=0.025):
#     it 1   residue: 3.3113e-02
#     it 2   residue: 3.8237e-03
#   increment 26 from t=0.625 to t=0.65 (dt=0.025):
#     it 1   residue: 3.1476e-02
#     it 2   residue: 3.4878e-03
#   increment 27 from t=0.65 to t=0.675 (dt=0.025):
#     it 1   residue: 3.0049e-02
#     it 2   residue: 3.2045e-03
#   increment 28 from t=0.675 to t=0.7 (dt=0.025):
#     it 1   residue: 2.8790e-02
#     it 2   residue: 2.9627e-03
#   increment 29 from t=0.7 to t=0.725 (dt=0.025):
#     it 1   residue: 2.7670e-02
#     it 2   residue: 2.7538e-03
#   increment 30 from t=0.725 to t=0.75 (dt=0.025):
#     it 1   residue: 2.6665e-02
#     it 2   residue: 2.5718e-03
#   increment 31 from t=0.75 to t=0.775 (dt=0.025):
#     it 1   residue: 2.5758e-02
#     it 2   residue: 2.4118e-03
#   increment 32 from t=0.775 to t=0.8 (dt=0.025):
#     it 1   residue: 2.4934e-02
#     it 2   residue: 2.2701e-03
#   increment 33 from t=0.8 to t=0.825 (dt=0.025):
#     it 1   residue: 3.4509e-02
#     it 2   residue: 2.1978e-03
#   increment 34 from t=0.825 to t=0.85 (dt=0.025):
#     it 1   residue: 3.4785e-02
#     it 2   residue: 8.2001e-05
#   increment 35 from t=0.85 to t=0.875 (dt=0.025):
#     it 1   residue: 7.5155e-04
#   increment 36 from t=0.875 to t=0.9 (dt=0.025):
#     it 1   residue: 7.5155e-04
#   increment 37 from t=0.9 to t=0.925 (dt=0.025):
#     it 1   residue: 7.5155e-04
#   increment 38 from t=0.925 to t=0.95 (dt=0.025):
#     it 1   residue: 7.5155e-04
#   increment 39 from t=0.95 to t=0.975 (dt=0.025):
#     it 1   residue: 7.5155e-04
#   increment 40 from t=0.975 to t=1.0 (dt=0.025):
#     it 1   residue: 7.5155e-04
#   time spent: 0.0h 0.0m 2.959s
# true

# %%
length(log_jnt_ips.book.tables)
# Out:
# 41

# %%
using PyPlot
for i=0:4:40
    tab = log_jnt_ips.book.tables[i+1]
    plot(tab[:y], tab[:tau], marker="o", label="inc $i")
end
legend();
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2b9b457550>)

# %%
using PyPlot
tab = log_jnt_ip.table
plot(tab[:ur], tab[:tau], marker="o");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2b992ea890>)

# %%
reset!(dom)
bc1 = BC(:node, "fixed_points", :(ux=0, uy=0, uz=0))
bc2 = BC(:node, "tip", :(uy=+0.0003))
solve!(dom, [bc1, bc2], nincs=10, autoinc=true, verbose=true)

bc2 = BC(:node, "tip", :(uy=-0.0001))
solve!(dom, [bc1, bc2], nincs=10, autoinc=true, verbose=true)

bc2 = BC(:node, "tip", :(uy=+0.0006))
solve!(dom, [bc1, bc2], nincs=10, autoinc=true, verbose=true)

bc2 = BC(:node, "tip", :(uy=-0.0006))
solve!(dom, [bc1, bc2], nincs=10, autoinc=true, verbose=true)

bc2 = BC(:node, "tip", :(uy=+0.005))
solve!(dom, [bc1, bc2], nincs=30, autoinc=true, verbose=true)
# Out:
# FEM analysis:
#   unknown dofs: 32
#   increment 1 from t=0.0 to t=0.1 (dt=0.1):
#     it 1   residue: 8.2054e-02
#     it 2   residue: 1.1611e-02
#     it 3   residue: 5.2704e-03
#   increment 2 from t=0.1 to t=0.2 (dt=0.1):
#     it 1   residue: 1.0423e-01
#     it 2   residue: 1.8570e-02
#     it 3   residue: 1.1566e-02
#     it 4   residue: 5.7570e-03
#   increment 3 from t=0.2 to t=0.3 (dt=0.1):
#     it 1   residue: 7.1183e-02
#     it 2   residue: 1.7820e-02
#     it 3   residue: 9.1686e-03
#   increment 4 from t=0.3 to t=0.4 (dt=0.1):
#     it 1   residue: 5.7490e-02
#     it 2   residue: 1.5975e-02
#     it 3   residue: 7.3276e-03
#   increment 5 from t=0.4 to t=0.5 (dt=0.1):
#     it 1   residue: 4.9496e-02
#     it 2   residue: 1.4013e-02
#     it 3   residue: 5.9428e-03
#   increment 6 from t=0.5 to t=0.6 (dt=0.1):
#     it 1   residue: 4.4155e-02
#     it 2   residue: 1.2514e-02
#     it 3   residue: 4.9854e-03
#   increment 7 from t=0.6 to t=0.7 (dt=0.1):
#     it 1   residue: 4.0264e-02
#     it 2   residue: 1.1338e-02
#     it 3   residue: 4.2845e-03
#   increment 8 from t=0.7 to t=0.8 (dt=0.1):
#     it 1   residue: 3.7267e-02
#     it 2   residue: 1.0387e-02
#     it 3   residue: 3.7480e-03
#   increment 9 from t=0.8 to t=0.9 (dt=0.1):
#     it 1   residue: 3.4866e-02
#     it 2   residue: 9.5989e-03
#   increment 10 from t=0.9 to t=1.0 (dt=0.1):
#     it 1   residue: 3.3008e-02
#     it 2   residue: 9.1772e-03
#   time spent: 0.0h 0.0m 1.2s
# FEM analysis:
#   unknown dofs: 32
#   increment 1 from t=0.0 to t=0.1 (dt=0.1):
#     it 1   residue: 3.0969e-02
#     it 2   residue: 1.1102e-16
#   increment 2 from t=0.1 to t=0.2 (dt=0.1):
#     it 1   residue: 2.1164e-16
#   increment 3 from t=0.2 to t=0.3 (dt=0.1):
#     it 1   residue: 2.1164e-16
#   increment 4 from t=0.3 to t=0.4 (dt=0.1):
#     it 1   residue: 2.1164e-16
#   increment 5 from t=0.4 to t=0.5 (dt=0.1):
#     it 1   residue: 2.1164e-16
#   increment 6 from t=0.5 to t=0.6 (dt=0.1):
#     it 1   residue: 2.1164e-16
#   increment 7 from t=0.6 to t=0.7 (dt=0.1):
#     it 1   residue: 2.1164e-16
#   increment 8 from t=0.7 to t=0.8 (dt=0.1):
#     it 1   residue: 2.1164e-16
#   increment 9 from t=0.8 to t=0.9 (dt=0.1):
#     it 1   residue: 2.1164e-16
#   increment 10 from t=0.9 to t=1.0 (dt=0.1):
#     it 1   residue: 2.1164e-16
#   time spent: 0.0h 0.0m 0.814s
# FEM analysis:
#   unknown dofs: 32
#   increment 1 from t=0.0 to t=0.1 (dt=0.1):
#     it 1   residue: 9.0206e-16
#   increment 2 from t=0.1 to t=0.2 (dt=0.1):
#     it 1   residue: 7.6399e-02
#     it 2   residue: 8.7798e-03
#   increment 3 from t=0.2 to t=0.3 (dt=0.1):
#     it 1   residue: 6.2052e-02
#     it 2   residue: 1.6903e-02
#     it 3   residue: 5.2296e-03
#   increment 4 from t=0.3 to t=0.4 (dt=0.1):
#     it 1   residue: 5.6606e-02
#     it 2   residue: 1.4832e-02
#     it 3   residue: 4.3395e-03
#   increment 5 from t=0.4 to t=0.5 (dt=0.1):
#     it 1   residue: 5.2563e-02
#     it 2   residue: 1.3339e-02
#     it 3   residue: 3.7159e-03
#   increment 6 from t=0.5 to t=0.6 (dt=0.1):
#     it 1   residue: 4.9290e-02
#     it 2   residue: 1.2144e-02
#     it 3   residue: 3.2373e-03
#   increment 7 from t=0.6 to t=0.7 (dt=0.1):
#     it 1   residue: 4.6571e-02
#     it 2   residue: 1.1162e-02
#     it 3   residue: 2.8588e-03
#   increment 8 from t=0.7 to t=0.8 (dt=0.1):
#     it 1   residue: 4.4263e-02
#     it 2   residue: 1.0337e-02
#     it 3   residue: 2.5525e-03
#   increment 9 from t=0.8 to t=0.9 (dt=0.1):
#     it 1   residue: 4.2273e-02
#     it 2   residue: 9.6344e-03
#   increment 10 from t=0.9 to t=1.0 (dt=0.1):
#     it 1   residue: 4.0629e-02
#     it 2   residue: 9.1721e-03
#   time spent: 0.0h 0.0m 0.91s
# FEM analysis:
#   unknown dofs: 32
#   increment 1 from t=0.0 to t=0.1 (dt=0.1):
#     it 1   residue: 2.4700e-01
#     it 2   residue: 2.4009e-15
#   increment 2 from t=0.1 to t=0.2 (dt=0.1):
#     it 1   residue: 9.4369e-16
#   increment 3 from t=0.2 to t=0.3 (dt=0.1):
#     it 1   residue: 9.4369e-16
#   increment 4 from t=0.3 to t=0.4 (dt=0.1):
#     it 1   residue: 9.4369e-16
#   increment 5 from t=0.4 to t=0.5 (dt=0.1):
#     it 1   residue: 9.1593e-16
#   increment 6 from t=0.5 to t=0.6 (dt=0.1):
#     it 1   residue: 9.1593e-16
#   increment 7 from t=0.6 to t=0.7 (dt=0.1):
#     it 1   residue: 3.9745e-02
#     it 2   residue: 1.0972e-05
#   increment 8 from t=0.7 to t=0.8 (dt=0.1):
#     it 1   residue: 1.4516e-01
#     it 2   residue: 6.7110e-04
#   increment 9 from t=0.8 to t=0.9 (dt=0.1):
#     it 1   residue: 5.6795e-02
#     it 2   residue: 6.8029e-04
#   increment 10 from t=0.9 to t=1.0 (dt=0.1):
#     it 1   residue: 3.4174e-02
#     it 2   residue: 3.1906e-04
#   time spent: 0.0h 0.0m 0.844s
# FEM analysis:
#   unknown dofs: 32
#   increment 1 from t=0.0 to t=0.0333333333 (dt=0.0333333333):
#     it 1   residue: 6.5830e-01
#     it 2   residue: 1.7764e-15
#   increment 2 from t=0.0333333333 to t=0.0666333333 (dt=0.0333):
#     it 1   residue: 2.0539e-15
#   increment 3 from t=0.0666333333 to t=0.0999333333 (dt=0.0333):
#     it 1   residue: 1.5276e-01
#     it 2   residue: 5.5564e-04
#   increment 4 from t=0.0999333333 to t=0.1332333333 (dt=0.0333):
#     it 1   residue: 2.4115e-01
#     it 2   residue: 2.4498e-02
#     it 3   residue: 5.8964e-03
#   increment 5 from t=0.1332333333 to t=0.1665333333 (dt=0.0333):
#     it 1   residue: 9.8338e-02
#     it 2   residue: 2.2949e-02
#     it 3   residue: 4.7674e-03
#   increment 6 from t=0.1665333333 to t=0.1998333333 (dt=0.0333):
#     it 1   residue: 1.1155e-01
#     it 2   residue: 2.0010e-02
#     it 3   residue: 3.8151e-03
#   increment 7 from t=0.1998333333 to t=0.2331333333 (dt=0.0333):
#     it 1   residue: 1.1888e-01
#     it 2   residue: 1.7180e-02
#     it 3   residue: 2.9913e-03
#   increment 8 from t=0.2331333333 to t=0.2664333333 (dt=0.0333):
#     it 1   residue: 1.2956e-01
#     it 2   residue: 1.9862e-02
#     it 3   residue: 3.5927e-03
#   increment 9 from t=0.2664333333 to t=0.2997333333 (dt=0.0333):
#     it 1   residue: 2.4117e-01
#     it 2   residue: 1.6012e-01
#     it 3   residue: 2.2724e-02
#     it 4   residue: 4.5404e-02
#     it 5   residue: 6.4746e-02
#     increment failed.
#   increment 9 from t=0.2664333333 to t=0.2831333333 (dt=0.0167):
#     it 1   residue: 1.3069e+00
#     it 2   residue: 1.7362e-01
#     it 3   residue: 7.0228e-02
#     it 4   residue: 2.6083e-03
#   increment 10 from t=0.2831333333 to t=0.3081333333 (dt=0.025):
#     it 1   residue: 4.4322e-01
#     it 2   residue: 2.6019e-02
#     it 3   residue: 9.7692e-03
#   increment 11 from t=0.3081333333 to t=0.3414333333 (dt=0.0333):
#     it 1   residue: 4.7424e-01
#     it 2   residue: 7.4585e-02
#     it 3   residue: 2.6017e-02
#     it 4   residue: 6.9782e-03
#   increment 12 from t=0.3414333333 to t=0.3747333333 (dt=0.0333):
#     it 1   residue: 1.4569e-01
#     it 2   residue: 2.8414e-02
#     it 3   residue: 6.1277e-03
#   increment 13 from t=0.3747333333 to t=0.4080333333 (dt=0.0333):
#     it 1   residue: 1.0372e-01
#     it 2   residue: 1.7985e-02
#     it 3   residue: 3.0952e-03
#   increment 14 from t=0.4080333333 to t=0.4413333333 (dt=0.0333):
#     it 1   residue: 7.9299e-02
#     it 2   residue: 1.2481e-02
#     it 3   residue: 1.8436e-03
#   increment 15 from t=0.4413333333 to t=0.4746333333 (dt=0.0333):
#     it 1   residue: 6.6215e-02
#     it 2   residue: 9.5335e-03
#   increment 16 from t=0.4746333333 to t=0.5079333333 (dt=0.0333):
#     it 1   residue: 5.5584e-02
#     it 2   residue: 7.4719e-03
#   increment 17 from t=0.5079333333 to t=0.5412333333 (dt=0.0333):
#     it 1   residue: 5.0559e-02
#     it 2   residue: 6.3312e-03
#   increment 18 from t=0.5412333333 to t=0.5745333333 (dt=0.0333):
#     it 1   residue: 4.6539e-02
#     it 2   residue: 5.4753e-03
#   increment 19 from t=0.5745333333 to t=0.6078333333 (dt=0.0333):
#     it 1   residue: 4.3293e-02
#     it 2   residue: 4.8164e-03
#   increment 20 from t=0.6078333333 to t=0.6411333333 (dt=0.0333):
#     it 1   residue: 4.0607e-02
#     it 2   residue: 4.2946e-03
#   increment 21 from t=0.6411333333 to t=0.6744333333 (dt=0.0333):
#     it 1   residue: 3.8340e-02
#     it 2   residue: 3.8719e-03
#   increment 22 from t=0.6744333333 to t=0.7077333333 (dt=0.0333):
#     it 1   residue: 3.6398e-02
#     it 2   residue: 3.5277e-03
#   increment 23 from t=0.7077333333 to t=0.7410333333 (dt=0.0333):
#     it 1   residue: 3.4812e-02
#     it 2   residue: 3.2517e-03
#   increment 24 from t=0.7410333333 to t=0.7743333333 (dt=0.0333):
#     it 1   residue: 3.3116e-02
#     it 2   residue: 2.9741e-03
#   increment 25 from t=0.7743333333 to t=0.8076333333 (dt=0.0333):
#     it 1   residue: 4.3482e-02
#     it 2   residue: 1.1340e-04
#   increment 26 from t=0.8076333333 to t=0.8409333333 (dt=0.0333):
#     it 1   residue: 1.0011e-03
#   increment 27 from t=0.8409333333 to t=0.8742333333 (dt=0.0333):
#     it 1   residue: 1.0011e-03
#   increment 28 from t=0.8742333333 to t=0.9075333333 (dt=0.0333):
#     it 1   residue: 1.0011e-03
#   increment 29 from t=0.9075333333 to t=0.9408333333 (dt=0.0333):
#     it 1   residue: 1.0011e-03
#   increment 30 from t=0.9408333333 to t=0.9741333333 (dt=0.0333):
#     it 1   residue: 1.0011e-03
#   increment 31 from t=0.9741333333 to t=1.0 (dt=0.0258666667):
#     it 1   residue: 7.7761e-04
#   time spent: 0.0h 0.0m 1.139s
# true

# %%
using PyPlot
tab = log_jnt_ip.table
plot(tab[:ur], tab[:tau], marker="o");
title("Slip vs contact shear stress")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2b98faff10>)
# PyObject <matplotlib.text.Text object at 0x7f2b98f21ed0>
